# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use("ggplot")

import sklearn
from sklearn.decomposition import TruncatedSVD

# %%
import pandas as pd

# Step 1: Load the data from the JSON file and show products
products = pd.read_json('../cleaning/products.json')
# Display the first few rows of the DataFrame
products.head()
# Out:
#    id                                              title  \
# 0   1  LANEIGE Lip Glowy Balm Stocking Stuffer: Hydra...
# 1   2  LANEIGE Lip Sleeping Mask Stocking Stuffer: No...
# 2   3  Elizabeth Arden Retinol + HPR Ceramide Capsule...
# 3   4  U Beauty - The U Beauty Duo - Resurfacing Comp...
# 4   5  BIODANCE Bio-Collagen Real Deep Mask, Hydratin...
#
#                                          description category   price  rating  \
# 0  laneige lip glowy balm stocking stuffer hydrat...   beauty   19.00     4.7
# 1  laneige lip sleeping mask stocking stuffer nou...   beauty   24.00     4.6
# 2  sponsored ad elizabeth arden retinol hpr ceram...   beauty   39.20     4.5
# 3  sponsored ad u beauty u beauty duo resurfacing...   beauty  138.00     4.3
# 4  biodance biocollagen real deep mask hydrating ...   beauty   20.24     4.3
#
#        stock                                              image reviews
# 0  Available  https://m.media-amazon.com/images/I/618NFh2d3H...      []
# 1  Available  https://m.media-amazon.com/images/I/71vornnrsq...      []
# 2  Available  https://m.media-amazon.com/images/I/71CeP1gEux...      []
# 3  Available  https://m.media-amazon.com/images/I/61lvIwYWPe...      []
# 4  Available  https://m.media-amazon.com/images/I/51299uVd3Y...      []

# %%
products.shape
# Out:
# (497, 9)

# %%
most_popular = products.sort_values('rating', ascending=False)
most_popular.head(8)
# Out:
#       id                                              title  \
# 335  359  Dokotoo Women's Casual Summer Dresses Fashion ...
# 190  207  Women Mom Christmas Gifts,Skin Care Set,for Ti...
# 100  112  Quacc Makeup Bag Sanitary Napkin Storage Bag w...
# 231  249  The Products Edge Sunglasses Men Polarized Sun...
# 12    14  Women Mom Christmas Gifts,Skin Care Set,for Ti...
# 355  380  Love Heart Necklace for Women 925 Sterling Sil...
# 276  296  5 Pairs Slip-on Nose Pads Covers,Soft Silicone...
# 264  283  Rimless Heart Sunglasses for Women Girls Trend...
#
#                                            description          category  \
# 335  sponsored ad dokotoo womens casual summer dres...    womens+dresses
# 190  women mom christmas giftsskin care setfor tigh...         skin+care
# 100  quacc makeup bag sanitary napkin storage bag z...       womens+bags
# 231  products edge sunglasses men polarized sunglas...        sunglasses
# 12   women mom christmas giftsskin care setfor tigh...            beauty
# 355  sponsored ad caricy love heart necklace women ...  womens+jewellery
# 276  pairs slipon nose pads coverssoft silicone eye...        sunglasses
# 264  breaksun rimless heart sunglasses women girls ...        sunglasses
#
#      price  rating      stock  \
# 335  26.88     5.0  Available
# 190  29.91     5.0  Available
# 100   3.99     5.0  Available
# 231   9.99     5.0  Available
# 12   29.91     5.0  Available
# 355  52.99     5.0  Available
# 276   8.99     5.0  Available
# 264  10.99     5.0  Available
#
#                                                  image reviews
# 335  https://m.media-amazon.com/images/I/71GgAQ4GZv...      []
# 190  https://m.media-amazon.com/images/I/81nisOkDAE...      []
# 100  https://m.media-amazon.com/images/I/71m05tv+tC...      []
# 231  https://m.media-amazon.com/images/I/31lbC7yqQd...      []
# 12   https://m.media-amazon.com/images/I/81nisOkDAE...      []
# 355  https://m.media-amazon.com/images/I/61TmFpsbbG...      []
# 276  https://m.media-amazon.com/images/I/61zh4z6hYQ...      []
# 264  https://m.media-amazon.com/images/I/518YHjRbwr...      []

# %%
# Count the number of products for each rating
rating_counts = products['rating'].value_counts().sort_index()

# Visualize the data as a bar chart
plt.figure(figsize=(8, 6))
rating_counts.plot(kind='bar', color='skyblue')
plt.title('Number of Products by Rating', fontsize=14)
plt.xlabel('Rating', fontsize=12)
plt.ylabel('Number of Products', fontsize=12)
plt.xticks(rotation=0)  # To make sure the X-axis labels are horizontal
plt.show()

# %%
# Count the number of products for each category
category_counts = products['category'].value_counts()

# Visualize the data as a bar chart
plt.figure(figsize=(10, 6))
category_counts.plot(kind='bar', color='lightcoral')
plt.title('Number of Products per Category', fontsize=14)
plt.xlabel('Category', fontsize=12)
plt.ylabel('Number of Products', fontsize=12)
plt.xticks(rotation=45, ha='right')  # Rotate X-axis labels for better readability
plt.tight_layout()  # Adjust layout to avoid clipping of labels
plt.show()
